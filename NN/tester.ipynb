# %%
import pandas as pd
import os
import shutil
print(os.getcwd())

for i in range(1,22):
    if not i==5:
        oft = pd.read_csv(f"./data/features/OFT_left_{i}.csv")
        print(f"video {i}: " + str(oft.isna().sum(axis = 0)["mouse_top.mouse_top_0.bodycentre.x"]) + " " + str(oft.isna().sum(axis = 0)["mouse_top.mouse_top_0.neck.x"]))
# Out:
# /Users/user/Desktop/FOKUS-PROJEKT/NN
# video 1: 62 62
# video 2: 70 74
# video 3: 60 60
# video 4: 78 78
# video 6: 14 14
# video 7: 27 27
# video 8: 30 30
# video 9: 29 29
# video 10: 29 29
# video 11: 19 19
# video 12: 28 28
# video 13: 24 25
# video 14: 28 28
# video 15: 19 19
# video 16: 49 51
# video 17: 12 12
# video 18: 8 8
# video 19: 19 19
# video 20: 36 36
# video 21: 18 18

# %%
oft = pd.read_csv(f"./data/features/OFT_left_1.csv")
print(oft["max_dim.x"].max())
print(oft["max_dim.y"].min())
# Out:
# 1280
# 1024
